# %% [markdown]
# # FRA502: Advanced Robotic Control and Simulation with ROS2 (ARCS2)

# %% [markdown]
# # Command Line Interface with Motorsim

# %% [markdown]
# ## Motorsim package system overview
# ![ARCS2.jpg](attachment:ARCS2.jpg)

# %% [markdown]
# ## Definition
# - `XX`  is your student ID in the format 6503, where 65 is your student year and 03 is your student number.

# %% [markdown]
# ## Install the package

# %% [markdown]
# 1. Source the setup files using `setup.bash`, as you are now in the **home directory**.

# %% [markdown]
# 2. Add sourcing into your shell startup script to avoid the necessity of sourcing the setup file each time a new shell is started.

# %% [markdown]
# 3. Source the setup file using `.bashrc`, as you are now in the **home directory**

# %% [markdown]
# ## Explore the package

# %% [markdown]
# 1. Execute the `demo_bringup.launch.py` **launch file** located in the `diffdrivekine` package.

# %% [markdown]
# 2. Visualize graph by rqt_graph

# %% [markdown]
# 3. Display the names of all active nodes.

# %% [markdown]
# 4. Display the names of all active topics.

# %% [markdown]
# 5. Display the names of all active services.

# %% [markdown]
# 6. Run the `teleop_twist_keyboard` **executable** located in the `teleop_twist_keyboard` package and remap the topic from `/cmd_vel` to `/Demo/input/cmd_vel`.

# %% [markdown]
# 7. Run the `rqt_service_caller` **executable** located in the `rqt_service_caller` package.

# %% [markdown]
# 8. Run the `rqt_topic` **executable** located in the `rqt_topic` package.

# %% [markdown]
# 9. Monitor the value of the topic `/Demo/cmd_vel`.

# %% [markdown]
# 10. Monitor frequency of topic `/Demo/cmd_vel`

# %% [markdown]
# ## Run Turtlesim package

# %% [markdown]
# 1. Run the `turtlesim_node` **executable** located in the `turtlesim` package.

# %% [markdown]
# 2. Display **type** of `/kill` service.

# %% [markdown]
# 3. Display the details of the **interface** of `turtlesim/srv/Kill`.

# %% [markdown]
# 4. Call the `/kill` service using the argument `name = turtle1`.

# %% [markdown]
# 5. Call the `/spawn` service using the argument `name = XX`.

# %% [markdown]
# ## Run diffdrivekine package

# %% [markdown]
# 1. Run the `diffdrive_fk.py` **executable** located in the `diffdrivekine` package and remap the topic from
#    - `/cmd_vel` to `/XX/cmd_vel`
#    - `/left/motor_speed` to `/XX/left/motor_speed`
#    - `/right/motor_speed` to `/XX/right/motor_speed`

# %% [markdown]
# 2. Run the `diffdrive_ik.py` **executable** located in the `diffdrivekine` package and remap the topic from
#    - `/cmd_vel` to `/XX/input/cmd_vel`
#    - `/left/cmd_vel` to `/XX/left/cmd_vel`
#    - `/right/cmd_vel` to `/XX/right/cmd_vel`

# %% [markdown]
# ## Run motorsim package

# %% [markdown]
# 1. Run the `controller_node.py` **executable** located in the `motorsim` package and remap the namespace to `/XX/left`

# %% [markdown]
# 2. Run the `controller_node.py` **executable** located in the `motorsim` package and remap the namespace to `/XX/right`

# %% [markdown]
# 3. Run the `motorsim_node.py` **executable** located in the `motorsim` package.

# %% [markdown]
# 4. Display **type** of `/spawn_motor` service.

# %% [markdown]
# 5. Display the details of the **interface** of `motorsim_interfaces/srv/MotorSpawn`.

# %% [markdown]
# 6. Call the `/spawn_motor` service using the argument `name = /XX/left`.

# %% [markdown]
# 7. Call the `/spawn_motor` service using the argument `name = /XX/right`.

# %% [markdown]
# ## Run teleop_twist_keyboard package

# %% [markdown]
# 1. Run the `teleop_twist_keyboard` **executable** located in the `teleop_twist_keyboard` package and remap the topic from `/cmd_vel` to `/XX/input/cmd_vel`.

# %% [markdown]
# ## Config Controller Node

# %% [markdown]
# 1. List all avaliable parameters.

# %% [markdown]
# 2. Set the controller parameter Kp of `XX/right/controller_node` to 0.1

# %% [markdown]
# 3. Set the controller parameter Ki of `XX/right/controller_node` to 0.01

# %% [markdown]
# 4. Set the controller parameter Kd of `XX/right/controller_node` to 0.0

# %% [markdown]
# 5. Set the controller parameter U_max of `XX/right/controller_node` to 18.0
